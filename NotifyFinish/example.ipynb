# %%
from NotifyFinish import notify_finish

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()

sender_email = os.environ.get('sender_email')
receiver_email = os.environ.get('receiver_email')
app_password = os.environ.get('app_password')

notify_finish(sender_email, receiver_email, app_password)
# Out:
# Successfully sent email

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
html_text = """
<html>
<body>

<h1>Your task has been finished.</h1>
<p>The cDFT task has been finished.</p>

</body>
</html>
"""

notify_finish(sender_email, receiver_email, app_password, text=html_text, body_type='html')
# Out:
# Successfully sent email

# %% [markdown]
# ![image.png](attachment:image.png)
